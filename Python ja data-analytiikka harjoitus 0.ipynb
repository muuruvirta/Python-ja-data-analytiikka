# %%
#OHJESOLU
#Suorita ensin tehtäväsolu ja kirjoita tämän jälkeen koodi koodisoluun. Kun koodi on valmis, suorita koodisolo
#ja tämän jälkeen tarkistussolu saadaksesi palautteen.

# %%
#TEHTÄVÄSOLU 1
#Alla on lista opiskelijoiden kurssisuorituksista. Laske jokaiselle opiskelijalle keskiarvo ja tallenna tulokset sanakirjaan nimeltä keskiarvot.

suoritukset = [
{"nimi": "Anna", "pisteet": [78, 85, 92]},
{"nimi": "Mikko", "pisteet": [65, 72, 70]},
{"nimi": "Liisa", "pisteet": [90, 95, 88]}
]

# %%
#KOODISOLU 1
#Kirjoita koodi tänne

# %%
#TARKISTUSSOLU 1
#ÄLÄ MUOKKAA TÄTÄ SOLUA!

assert isinstance(keskiarvot, dict)
assert keskiarvot["Anna"] == 85.0
assert keskiarvot["Mikko"] == 69.0
assert keskiarvot["Liisa"] == 91.0
print("Tehtävä 1 oikein!")

# %%
#TEHTÄVÄSOLU 2
#Poimi vain ne tuotteet, joiden myynti on vähintään 100 kappaletta. Sijoita tulokset taulukkoon 
#suositut tuotteet.

myynnit = [("Tuote A", 120),("Tuote B", 80),("Tuote C", 150),("Tuote D", 95),("Tuote E", 200)
]

# %%
#KOODISOLU 2
#Kirjoita koodi tänne

# %%
#TARKISTUSSOLU 2
#ÄLÄ MUOKKAA TÄTÄ SOLUA!

assert suositut_tuotteet == ["Tuote A", "Tuote C", "Tuote E"]
print("Tehtävä 2 oikein!")

# %%
#TEHTÄVÄSOLU 3

#Alla on lista opiskelijoiden kurssisuorituksista. Jokaisella opiskelijalla on useita tehtäväpisteitä.
#1. Laske jokaiselle opiskelijalle keskiarvo.
#2. Tallenna tulokset sanakirjaan nimeltä keskiarvot, jossa avaimena on opiskelijan nimi ja arvona keskiarvo.
#3. Selvitä kurssin korkeimman keskiarvon saanut opiskelija.
#4. Luo lista niistä opiskelijoista, joiden keskiarvo on vähintään 85 muodossa Opiskelija: pistemäärä yhden desimaalin tarkkuudella
#   Esim. Anna: 23.5
#5. Tulosta lopuksi kaikkien opiskelijoiden keskiarvot, paras opiskelija ja hänen pistemääränsä. Esim. Matti (97.0) sekä ne opiskelijat, 
#   joiden keskiarvo on vähintään 85 pistettä. 

suoritukset = [
{"nimi": "Anna", "pisteet": [78, 85, 90, 88]},
{"nimi": "Mikko", "pisteet": [65, 70, 72, 68]},
{"nimi": "Sara", "pisteet": [92, 95, 91, 96]},
{"nimi": "Juha", "pisteet": [80, 79, 83, 81]},
{"nimi": "Emma", "pisteet": [88, 90, 85, 92]}
]

# %%
#KOODISOLU 3
#Kirjoita koodi tänne

# %%
#TARKISTUSSOLU 3
#ÄLÄ MUOKKAA TÄTÄ SOLUA!

assert isinstance(keskiarvot, dict), "keskiarvot tulee olla sanakirja"
assert round(keskiarvot["Anna"], 2) == 85.25
assert round(keskiarvot["Mikko"], 2) == 68.75
assert round(keskiarvot["Sara"], 2) == 93.50
assert round(keskiarvot["Juha"], 2) == 80.75
assert round(keskiarvot["Emma"], 2) == 88.75
print("Tehtävä ratkaistu oikein!")
